# %%
"""
This module was taken from target-pred-py https://github.com/ikmckenz/target-pred-py/blob/master/src/data/chembl_etl.py

This module will download the SQLite version of the ChEMBL database if it
doesn't exist in data/, and use it to create the interim data sets.
"""
# Out:
# "\nThis module was taken from target-pred-py https://github.com/ikmckenz/target-pred-py/blob/master/src/data/chembl_etl.py\n\nThis module will download the SQLite version of the ChEMBL database if it\ndoesn't exist in data/, and use it to create the interim data sets.\n"

# %%
import csv
import os
import sqlite3
import tarfile
import urllib.request

# %%
OLD_QUERY = """
            SELECT 
                canonical_smiles, published_value, published_units, pref_name
            FROM 
                compound_structures as cs, activities as ac, assays as assays, target_dictionary as td
            WHERE 
                cs.molregno = ac.molregno 
            AND
                /* Endpoint is Ki*/
                ac.bao_endpoint = "BAO_0000192"
            AND
                ac.published_value IS NOT NULL
            AND
                ac.assay_id = assays.assay_id
            AND
                assays.tid = td.tid
            AND
                td.pref_name != "Unchecked"
            AND
                td.organism = "Homo sapiens"
            """

SWISS_QUERY = """
                SELECT
                    canonical_smiles, standard_value, standard_units, pref_name
                FROM
                    compound_structures as cs, target_dictionary as td, assays, activities, compound_properties
                WHERE
                    compound_properties.molregno = cs.molregno
                AND
                    cs.molregno = activities.molregno
                AND
                    activities.assay_id = assays.assay_id
                AND 
                    assays.tid = td.tid
                AND
                    assays.assay_organism = "Homo sapiens"
                AND
                    assays.assay_type = "B"
                AND
                    activities.type IN ("Ki","Kd","IC50","EC50")
                AND
                    activities.standard_units IN ("mM", "uM","nM")
                AND
                    activities.standard_relation in ("=", "<", "<=")
                AND
                    compound_properties.heavy_atoms < 80
                AND
                    td.target_type IN ("SINGLE PROTEIN", "PROTEIN COMPLEX")
              """

CYP_ASSAY_QUERY = """
                SELECT
                    canonical_smiles, standard_value, standard_units, pref_name
                FROM
                    compound_structures as cs, target_dictionary as td, assays, activities, compound_properties
                WHERE
                    compound_properties.molregno = cs.molregno
                AND
                    cs.molregno = activities.molregno
                AND
                    activities.assay_id = assays.assay_id
                AND 
                    assays.tid = td.tid
                AND
                    assays.assay_organism = "Homo sapiens"
                AND
                    assays.assay_type = "A"
                AND
                    activities.type IN ("Ki","Kd","IC50","EC50")
                AND
                    activities.standard_units IN ("mM", "uM","nM")
                AND
                    activities.standard_relation in ("=", "<", "<=")
                AND
                    compound_properties.heavy_atoms < 80
                AND
                    td.target_type IN ("SINGLE PROTEIN", "PROTEIN COMPLEX")
              """

# %%
class ChEMBL_SQLite:  # pylint: disable=invalid-name
    """ChEMBL data http://www.ebi.ac.uk/chembl version chembl_24_1.

    Args:
        path (string, optional): Where the data will be downloaded. Defaults to
            the `data` directory of code.
    """
    url = "ftp://ftp.ebi.ac.uk/pub/databases/chembl/ChEMBLdb/releases/chembl_25/"
    filename = "chembl_25_sqlite.tar.gz"
    dbpath = "chembl_25/chembl_25_sqlite/chembl_25.db"
    csvfilename = "../interim/smiles_to_activity.csv"

    def __init__(self, path="../data/external/"):
        self.path = path

    def get_raw_data(self):
        """Will create the raw data if it does not already exist."""
        if not os.path.isfile(self.path + self.csvfilename):
            self._write_raw_data(query=SWISS_QUERY)

    def db_connect(self):
        """Returns a connection to the ChEMBL database,
        will download if it does not exist.

        Returns:
            conn (sqlite3.Connection): The connection to the database
        """
        if not os.path.isfile(self.path + self.dbpath):
            self._download()

        conn = sqlite3.connect(self.path + self.dbpath)
        return conn

    def _write_raw_data(self, query):
        """This runs the query to get our data from the database
        For now this query returns good-enough data to do a quick analysis,
        this is not the final query.
        """

        conn = self.db_connect()
        print("Running SQL query")
        cur = conn.execute(query)
        headers = [x[0] for x in cur.description]
        data_table = cur.fetchall()

        with open(self.path + self.csvfilename, "w") as f:
            writer = csv.writer(f)
            writer.writerow(headers)
            writer.writerows(data_table)

    def _download(self):
        """Downloads the ChEMBL database if it doesn't exist"""
        if not os.path.isfile(self.path + self.dbpath):
            delete_tar = False

            if not os.path.isfile(self.path + self.filename):
                delete_tar = True
                print("Downloading ChEMBL database")
                urllib.request.urlretrieve(self.url + self.filename,
                                           self.path + self.filename)

            print("Extracting tarfile")
            tarfile.open(self.path + self.filename).extractall(path=self.path)
            if delete_tar:
                os.remove(self.path + self.filename)

# %%
cs = ChEMBL_SQLite()

# %%
conn = cs.db_connect()

# %%
# dbconn = cs.db_connect('data/external/chembl_25/chembl_25_sqlite/chembl_25.db')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-d4e269b80ab9> in <module>
# ----> 1 dbconn = cs.db_connect('data/external/chembl_25/chembl_25_sqlite/chembl_25.db')
#
# TypeError: db_connect() takes 1 positional argument but 2 were given

# %%
c = conn.cursor()

# %%
query = c.execute(SWISS_QUERY)

# %%
print(c.fetchone())
# Out:
# ('COc1cc(N)c(Cl)cc1C(=O)OCCN2CCN(CC2)c3ncccn3', 4.5, 'nM', 'Serotonin 4 (5-HT4) receptor')

# %%
import pandas as pd

# %%
SQL_Query = pd.read_sql_query(SWISS_QUERY, conn)

# %%
df = pd.DataFrame(SQL_Query)

# %%
df.head(30)
# Out:
#                                      canonical_smiles  standard_value  \
# 0         COc1cc(N)c(Cl)cc1C(=O)OCCN2CCN(CC2)c3ncccn3             4.5
# 1         COc1cc(N)c(Cl)cc1C(=O)OCCN2CCN(CC2)c3ncccn3            66.0
# 2                   O=C1C=CC=C2[C@H]3CNC[C@H](C3)CN12         26000.0
# 3                   O=C1C=CC=C2[C@H]3CNC[C@H](C3)CN12        100000.0
# 4                                   CNCC\C=C\c1cccnc1         46000.0
# 5                          CN1CCC[C@H]1COc2ccc(Cl)nc2          1400.0
# 6                         CCc1cncc(OC[C@@H]2CCCN2C)c1          1000.0
# 7                             Clc1ccc(cn1)C2CC3CCC2N3             7.0
# 8                             Clc1ccc(cn1)C2CC3CCC2N3           200.0
# 9   C[C@H](CCC(=O)NCC(=O)O)[C@H]1CC[C@H]2[C@@H]3[C...          3000.0
# 10                         CN1CCC[C@H]1COc2ccc(Br)nc2          2600.0
# 11                            Cc1ncccc1OC[C@@H]2CCCN2         30000.0
# 12                          CN1CCC[C@H]1COc2ccc(C)nc2          2200.0
# 13                            CN1CCC[C@H]1COc2cnccc2C          2100.0
# 14                         CN1CCC[C@H]1COc2cncc(Br)c2          5950.0
# 15                            C(Oc1cccnc1)[C@@H]2CCN2           700.0
# 16                            CN1CCC[C@H]1COc2cccnc2C          4800.0
# 17                               CN1CCC[C@H]1c2cccnc2         21000.0
# 18                               CN1CCC[C@H]1c2cccnc2        160000.0
# 19                      [I-].CC(=O)C1=CC[N+](C)(C)CC1           100.0
# 20  C[C@H](CCC(=O)O)[C@H]1CC[C@H]2[C@@H]3[C@H](O)C...          8660.0
# 21  C[C@H](CCC(=O)O)C1CC[C@H]2[C@@H]3[C@H](O)[C@H]...           750.0
# 22                             CN1CCC[C@H]1COc2cccnc2           750.0
# 23     Clc1cccc(c1)N2CCN(Cc3cncn3Cc4ccc(cc4)C#N)CC2=O          6800.0
# 24                             CN1CCC[C@H]1COc2cccnc2         19000.0
# 25  C[C@H](CCC(=O)NCCS(=O)(=O)O)[C@H]1CC[C@H]2[C@@...          3000.0
# 26                          CN1CCC[C@H]1COc2cncc(C)c2          2300.0
# 27  CCC[C@H]1[C@@H](O)[C@H]2[C@@H]3CCC([C@H](C)CCC...          1110.0
# 28                             CN1CCC[C@H]1c2onc(C)c2         64000.0
# 29                             CN1CCC[C@H]1c2onc(C)c2        411000.0
#
#    standard_units                                      pref_name
# 0              nM                   Serotonin 4 (5-HT4) receptor
# 1              nM                   Serotonin 4 (5-HT4) receptor
# 2              nM  Neuronal acetylcholine receptor; alpha3/beta4
# 3              nM     Acetylcholine receptor protein delta chain
# 4              nM  Neuronal acetylcholine receptor; alpha3/beta4
# 5              nM  Neuronal acetylcholine receptor; alpha4/beta2
# 6              nM  Neuronal acetylcholine receptor; alpha4/beta2
# 7              nM  Neuronal acetylcholine receptor; alpha3/beta4
# 8              nM     Acetylcholine receptor protein delta chain
# 9              nM                         Bile acid receptor FXR
# 10             nM  Neuronal acetylcholine receptor; alpha4/beta2
# 11             nM     Acetylcholine receptor protein delta chain
# 12             nM  Neuronal acetylcholine receptor; alpha4/beta2
# 13             nM  Neuronal acetylcholine receptor; alpha4/beta2
# 14             nM  Neuronal acetylcholine receptor; alpha4/beta2
# 15             nM  Neuronal acetylcholine receptor; alpha3/beta4
# 16             nM  Neuronal acetylcholine receptor; alpha4/beta2
# 17             nM  Neuronal acetylcholine receptor; alpha3/beta4
# 18             nM     Acetylcholine receptor protein delta chain
# 19             nM     Acetylcholine receptor protein delta chain
# 20             nM                         Bile acid receptor FXR
# 21             nM                         Bile acid receptor FXR
# 22             nM  Neuronal acetylcholine receptor; alpha4/beta2
# 23             nM              Geranylgeranyl transferase type I
# 24             nM     Acetylcholine receptor protein delta chain
# 25             nM                         Bile acid receptor FXR
# 26             nM  Neuronal acetylcholine receptor; alpha4/beta2
# 27             nM                         Bile acid receptor FXR
# 28             nM  Neuronal acetylcholine receptor; alpha3/beta4
# 29             nM     Acetylcholine receptor protein delta chain

# %%
df.shape
# Out:
# (544894, 4)

# %%
# str_choice = "cyp450|CYP450|cyp"

# %%
cyp_df = df[df['pref_name'].str.contains('cytochrome', na=False)]
cyp_df.info
# Out:
# <bound method DataFrame.info of Empty DataFrame
# Columns: [canonical_smiles, standard_value, standard_units, pref_name]
# Index: []>

# %%
CYP_ASSAY_Query = pd.read_sql_query(CYP_ASSAY_QUERY, conn)

# %%
cyp_df = pd.DataFrame(CYP_ASSAY_QUERY)

# %%
# cypquery = df['pref_name']
